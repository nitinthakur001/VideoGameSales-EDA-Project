# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.shape[1] #col
# Out:
# 15

# %%
df.shape[0] #rows
# Out:
# 5909

# %%
df=df[df.duplicated()]
df
# Out:
#       Rank                                               Name Platform  Year  \
# 10       9                          New Super Mario Bros. Wii      Wii  2010
# 11       9                          New Super Mario Bros. Wii      Wii  2010
# 12       9                          New Super Mario Bros. Wii      Wii  2010
# 65      60                                     Super Mario 64       DS  2010
# 66      60                                     Super Mario 64       DS  2010
# 381    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 382    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 1659  1649                                         WCW Mayhem       PS  2015
# 1660  1649                                         WCW Mayhem       PS  2015
# 5889  5876                                 Dynasty Warriors 6     X360  2017
# 5890  5876                                 Dynasty Warriors 6     X360  2017
#
#      Month     Genre        Publisher        Country       City  \
# 10     Sep  Platform         Nintendo            USA  Fairfield
# 11     Sep  Platform         Nintendo            USA  Fairfield
# 12     Sep  Platform         Nintendo            USA  Fairfield
# 65     Dec  Platform         Nintendo  United States    Seattle
# 66     Dec  Platform         Nintendo  United States    Seattle
# 381    Jan  Platform         Nintendo  United States  Lancaster
# 382    Jan  Platform         Nintendo  United States  Lancaster
# 1659   Apr  Fighting  Electronic Arts  United States      Akron
# 1660   Apr  Fighting  Electronic Arts  United States      Akron
# 5889   Jul    Action       Tecmo Koei      Australia     Sydney
# 5890   Jul    Action       Tecmo Koei      Australia     Sydney
#
#                 State Region NA_Sales  Global_Sales  NA_Profit  Global_Profit
# 10               Ohio   East   $14.59         28.62      4.377          8.586
# 11               Ohio   East   $14.59         28.62      4.377          8.586
# 12               Ohio   East   $14.59         28.62      4.377          8.586
# 65         Washington   West     5.08         10.42      1.524          3.126
# 66         Washington   West     5.08         10.42      1.524          3.126
# 381              Ohio   East     1.17          3.51      0.351          1.053
# 382              Ohio   East     1.17          3.51      0.351          1.053
# 1659             Ohio   East     0.68          1.22      0.204          0.366
# 1660             Ohio   East     0.68          1.22      0.204          0.366
# 5889  New South Wales   West     0.15          0.30      0.045          0.090
# 5890  New South Wales   West     0.15          0.30      0.045          0.090

# %%
df.shape[0]
# Out:
# 11

# %%
df=df.drop_duplicates()
df['Region']=df['Region'].fillna('North')
df
# Out:
#       Rank                                               Name Platform  Year  \
# 10       9                          New Super Mario Bros. Wii      Wii  2010
# 65      60                                     Super Mario 64       DS  2010
# 381    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 1659  1649                                         WCW Mayhem       PS  2015
# 5889  5876                                 Dynasty Warriors 6     X360  2017
#
#      Month     Genre        Publisher        Country       City  \
# 10     Sep  Platform         Nintendo            USA  Fairfield
# 65     Dec  Platform         Nintendo  United States    Seattle
# 381    Jan  Platform         Nintendo  United States  Lancaster
# 1659   Apr  Fighting  Electronic Arts  United States      Akron
# 5889   Jul    Action       Tecmo Koei      Australia     Sydney
#
#                 State Region NA_Sales  Global_Sales  NA_Profit  Global_Profit
# 10               Ohio   East   $14.59         28.62      4.377          8.586
# 65         Washington   West     5.08         10.42      1.524          3.126
# 381              Ohio   East     1.17          3.51      0.351          1.053
# 1659             Ohio   East     0.68          1.22      0.204          0.366
# 5889  New South Wales   West     0.15          0.30      0.045          0.090

# %%
df=df[df['Region'].isnull()]
df.shape[0]
# Out:
# 0

# %%
df.head(100)
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Month, Genre, Publisher, Country, City, State, Region, NA_Sales, Global_Sales, NA_Profit, Global_Profit]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Month, Genre, Publisher, Country, City, State, Region, NA_Sales, Global_Sales, NA_Profit, Global_Profit]
# Index: []

# %%
df=pd.read_csv('D:/Downloads/DataSets/VideoGamesProject-main/VideoGamesProject-main/VideoGamesSales.csv')
df=df.drop_duplicates()
df['Region']=df['Region'].fillna('North')
df.head(100)
# Out:
#      Rank                                    Name Platform  Year Month  \
# 0       1                              Wii Sports      Wii  2010   Jan
# 1       2                       Super Mario Bros.      NES  2010   Feb
# 2       3                          Mario Kart Wii      Wii  2010   Mar
# 3       4                       Wii Sports Resort      Wii  2010   Apr
# 4       5                Pokemon Red/Pokemon Blue       GB  2010   May
# ..    ...                                     ...      ...   ...   ...
# 102    96  Crash Bandicoot 2: Cortex Strikes Back       PS  2010   Dec
# 103    97                     Super Mario Bros. 2      NES  2010   Jan
# 104    98     Super Smash Bros. for Wii U and 3DS      3DS  2010   Feb
# 105    99              Call of Duty: World at War     X360  2010   Mar
# 106   100                           Battlefield 3     X360  2010   Apr
#
#             Genre                    Publisher        Country           City  \
# 0          Sports                     Nintendo  United States      Fairfield
# 1        Platform                     Nintendo  United States        Edmonds
# 2          Racing                     Nintendo  United States     Louisville
# 3          Sports                     Nintendo  United States     Round Rock
# 4    Role-Playing                     Nintendo  United States      Nashville
# ..            ...                          ...            ...            ...
# 102      Platform  Sony Computer Entertainment  United States        Garland
# 103      Platform                     Nintendo  United States         Tucson
# 104      Fighting                     Nintendo            USA         Tucson
# 105       Shooter                   Activision            USA  New York City
# 106       Shooter              Electronic Arts            USA  New York City
#
#           State   Region NA_Sales  Global_Sales  NA_Profit  Global_Profit
# 0    California     West   $41.49         82.74     12.447         24.822
# 1    Washington     West   $29.08         40.24      8.724         12.072
# 2      Kentucky    South   $15.85         35.82      4.755         10.746
# 3         Texas  Central   $15.75         33.00      4.725          9.900
# 4     Tennessee    South   $11.27         31.37      3.381          9.411
# ..          ...      ...      ...           ...        ...            ...
# 102       Texas  Central     3.78          7.58      1.134          2.274
# 103     Arizona     West     5.39          7.46      1.617          2.238
# 104     Arizona     West     3.24          7.45      0.972          2.235
# 105    New York     East     4.79          7.37      1.437          2.211
# 106    New York     East     4.46          7.34      1.338          2.202
#
# [100 rows x 15 columns]

# %%
df.tail(100)
# Out:
#       Rank                                       Name Platform  Year Month  \
# 5806  5795                                NBA Live 08      PSP  2017   Oct
# 5807  5796                  The King of Fighters XIII      PS3  2017   Nov
# 5808  5797                       NCAA Final Four 2002      PS2  2017   Dec
# 5809  5798               South Park: Chef's Luv Shack       PS  2017   Jan
# 5810  5799                                Music Maker      PS2  2017   Feb
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#            Genre                    Publisher    Country    City  \
# 5806      Sports              Electronic Arts  Australia  Sydney
# 5807    Fighting            Rising Star Games  Australia  Sydney
# 5808      Sports  Sony Computer Entertainment  Australia  Sydney
# 5809        Misc        Acclaim Entertainment  Australia  Sydney
# 5810        Misc                        Magix  Australia  Sydney
# ...          ...                          ...        ...     ...
# 5904      Racing                          THQ  Australia  Sydney
# 5905  Simulation              Electronic Arts  Australia  Sydney
# 5906      Action              Electronic Arts  Australia  Sydney
# 5907      Action                   Activision  Australia  Sydney
# 5908  Simulation           Namco Bandai Games  Australia  Sydney
#
#                 State Region NA_Sales  Global_Sales  NA_Profit  Global_Profit
# 5806  New South Wales   West     0.28          0.31      0.084          0.093
# 5807  New South Wales   West     0.17          0.31      0.051          0.093
# 5808  New South Wales   West     0.15          0.31      0.045          0.093
# 5809  New South Wales   West     0.17          0.31      0.051          0.093
# 5810  New South Wales   West     0.15          0.31      0.045          0.093
# ...               ...    ...      ...           ...        ...            ...
# 5904  New South Wales   West     0.21          0.30      0.063          0.090
# 5905  New South Wales   West     0.15          0.30      0.045          0.090
# 5906  New South Wales   West     0.24          0.30      0.072          0.090
# 5907  New South Wales   West     0.17          0.30      0.051          0.090
# 5908  New South Wales   West        0          0.30      0.000          0.090
#
# [100 rows x 15 columns]

# %%
df
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# 0           Sports            Nintendo  United States   Fairfield
# 1         Platform            Nintendo  United States     Edmonds
# 2           Racing            Nintendo  United States  Louisville
# 3           Sports            Nintendo  United States  Round Rock
# 4     Role-Playing            Nintendo  United States   Nashville
# ...            ...                 ...            ...         ...
# 5904        Racing                 THQ      Australia      Sydney
# 5905    Simulation     Electronic Arts      Australia      Sydney
# 5906        Action     Electronic Arts      Australia      Sydney
# 5907        Action          Activision      Australia      Sydney
# 5908    Simulation  Namco Bandai Games      Australia      Sydney
#
#                 State   Region NA_Sales  Global_Sales  NA_Profit  \
# 0          California     West   $41.49         82.74     12.447
# 1          Washington     West   $29.08         40.24      8.724
# 2            Kentucky    South   $15.85         35.82      4.755
# 3               Texas  Central   $15.75         33.00      4.725
# 4           Tennessee    South   $11.27         31.37      3.381
# ...               ...      ...      ...           ...        ...
# 5904  New South Wales     West     0.21          0.30      0.063
# 5905  New South Wales     West     0.15          0.30      0.045
# 5906  New South Wales     West     0.24          0.30      0.072
# 5907  New South Wales     West     0.17          0.30      0.051
# 5908  New South Wales     West        0          0.30      0.000
#
#       Global_Profit
# 0            24.822
# 1            12.072
# 2            10.746
# 3             9.900
# 4             9.411
# ...             ...
# 5904          0.090
# 5905          0.090
# 5906          0.090
# 5907          0.090
# 5908          0.090
#
# [5893 rows x 15 columns]

# %%
df['NA_Sales']=df['NA_Sales'].replace('[$]','',regex=True)
df
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# 0           Sports            Nintendo  United States   Fairfield
# 1         Platform            Nintendo  United States     Edmonds
# 2           Racing            Nintendo  United States  Louisville
# 3           Sports            Nintendo  United States  Round Rock
# 4     Role-Playing            Nintendo  United States   Nashville
# ...            ...                 ...            ...         ...
# 5904        Racing                 THQ      Australia      Sydney
# 5905    Simulation     Electronic Arts      Australia      Sydney
# 5906        Action     Electronic Arts      Australia      Sydney
# 5907        Action          Activision      Australia      Sydney
# 5908    Simulation  Namco Bandai Games      Australia      Sydney
#
#                 State   Region NA_Sales  Global_Sales  NA_Profit  \
# 0          California     West    41.49         82.74     12.447
# 1          Washington     West    29.08         40.24      8.724
# 2            Kentucky    South    15.85         35.82      4.755
# 3               Texas  Central    15.75         33.00      4.725
# 4           Tennessee    South    11.27         31.37      3.381
# ...               ...      ...      ...           ...        ...
# 5904  New South Wales     West     0.21          0.30      0.063
# 5905  New South Wales     West     0.15          0.30      0.045
# 5906  New South Wales     West     0.24          0.30      0.072
# 5907  New South Wales     West     0.17          0.30      0.051
# 5908  New South Wales     West        0          0.30      0.000
#
#       Global_Profit
# 0            24.822
# 1            12.072
# 2            10.746
# 3             9.900
# 4             9.411
# ...             ...
# 5904          0.090
# 5905          0.090
# 5906          0.090
# 5907          0.090
# 5908          0.090
#
# [5893 rows x 15 columns]

# %%
df['NA_Sales']=pd.to_numeric(df['NA_Sales'],errors='coerce')
df
Average_Sales=df['NA_Sales'].mean()
Average_Sales

df['NA_Sales']=df['NA_Sales'].fillna(Average_Sales)
df
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# 0           Sports            Nintendo  United States   Fairfield
# 1         Platform            Nintendo  United States     Edmonds
# 2           Racing            Nintendo  United States  Louisville
# 3           Sports            Nintendo  United States  Round Rock
# 4     Role-Playing            Nintendo  United States   Nashville
# ...            ...                 ...            ...         ...
# 5904        Racing                 THQ      Australia      Sydney
# 5905    Simulation     Electronic Arts      Australia      Sydney
# 5906        Action     Electronic Arts      Australia      Sydney
# 5907        Action          Activision      Australia      Sydney
# 5908    Simulation  Namco Bandai Games      Australia      Sydney
#
#                 State   Region  NA_Sales  Global_Sales  NA_Profit  \
# 0          California     West     41.49         82.74     12.447
# 1          Washington     West     29.08         40.24      8.724
# 2            Kentucky    South     15.85         35.82      4.755
# 3               Texas  Central     15.75         33.00      4.725
# 4           Tennessee    South     11.27         31.37      3.381
# ...               ...      ...       ...           ...        ...
# 5904  New South Wales     West      0.21          0.30      0.063
# 5905  New South Wales     West      0.15          0.30      0.045
# 5906  New South Wales     West      0.24          0.30      0.072
# 5907  New South Wales     West      0.17          0.30      0.051
# 5908  New South Wales     West      0.00          0.30      0.000
#
#       Global_Profit
# 0            24.822
# 1            12.072
# 2            10.746
# 3             9.900
# 4             9.411
# ...             ...
# 5904          0.090
# 5905          0.090
# 5906          0.090
# 5907          0.090
# 5908          0.090
#
# [5893 rows x 15 columns]

# %%
df['Country']=df['Country'].replace({'USA':'United States'})
df['Country']=df['Country'].str.title()
df=df[df['Country']=='Australia']
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Month, Genre, Publisher, Country, City, State, Region, NA_Sales, Global_Sales, NA_Profit, Global_Profit]
# Index: []

# %%
df=pd.read_csv('D:/Downloads/DataSets/VideoGamesProject-main/VideoGamesProject-main/VideoGamesSales.csv')
df=df.drop_duplicates()
df['Region']=df['Region'].fillna('North')
df['NA_Sales']=df['NA_Sales'].replace('[$]','',regex=True)
df['NA_Sales']=pd.to_numeric(df['NA_Sales'],errors='coerce')
Average_Sales=df['NA_Sales'].mean()
Average_Sales

df['NA_Sales']=df['NA_Sales'].fillna(Average_Sales)
df['Country']=df['Country'].replace({'USA':'United States'})
df['Country']=df['Country'].str.title()

df=df.rename(columns={'NA_Sales':'National Sales','Global_Sales':'Global Sales','NA_Profit':'National Profit','Global_Profit':'Global Profit'})


sales_cap=df['Global Sales'].quantile(0.95)
sales_cap

df['National Sales']=np.where(df['National Sales']>sales_cap, sales_cap, df['Global Sales'])


#create a barchart
National_Sales=df.groupby(['Region','Country'])['National Sales'].sum().reset_index().sort_values(by='National Sales',ascending=False)
National_Sales

plt.figure(figsize=(16,8))
sns.barplot(data=National_Sales, x='Region',y='National Sales',hue='Country')
plt.title('National Sales By Region And Country',fontweight='bold')
plt.xlabel('Region',fontweight='bold')
plt.ylabel('National Sales',fontweight='bold')
plt.show()

# %%
#create Box Plot
plt.figure(figsize=(10,6))
sns.boxplot(x='Country',y='National Sales',data=df,showmeans=True,hue='Genre',meanprops={"marker":"o"
                                                                                        ,"marherfacecolor":"white"
                                                                                        ,"markersize":"6"
                                                                                        ,"markeredgecolor":"green"})

plt.title('National Sales By Country',fontweight='bold')
plt.xlabel('Country',fontweight='bold')
plt.ylabel('National Sales',fontweight='bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 #create Box Plot
#       2 plt.figure(figsize=(10,6))
# ----> 3 sns.boxplot(x='Country',y='National Sales',data=df,showmeans=True,hue='Genre',meanprops={"marker":"o"
#       4                                                                                         ,"marherfacecolor":"white"
#       5                                                                                         ,"markersize":"6"
#       6                                                                                         ,"markeredgecolor":"green"})
#       8 plt.title('National Sales By Country',fontweight='bold')
#       9 plt.xlabel('Country',fontweight='bold')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
#    1635     width=width,
#    1636     dodge=dodge,
#    1637     gap=gap,
#    1638     fill=fill,
#    1639     whis=whis,
#    1640     color=color,
#    1641     linecolor=linecolor,
#    1642     linewidth=linewidth,
#    1643     fliersize=fliersize,
#    1644     plot_kws=kwargs,
#    1645 )
#    1647 p._add_axis_labels(ax)
#    1648 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\categorical.py:700, in _CategoricalPlotter.plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     679 default_kws = dict(
#     680     bxpstats=stats.to_dict("records"),
#     681     positions=data[self.orient],
#    (...)    697     )
#     698 )
#     699 boxplot_kws = {**default_kws, **plot_kws}
# --> 700 artists = ax.bxp(**boxplot_kws)
#     702 # Reset artist widths after adding so everything stays positive
#     703 ori_idx = ["x", "y"].index(self.orient)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_axes.py:4566, in Axes.bxp(self, bxpstats, positions, widths, vert, orientation, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder, capwidths, label)
#    4561         means.append(do_plot(
#    4562             [box_left, box_right], [stats['mean'], stats['mean']],
#    4563             **mean_kw
#    4564         ))
#    4565     else:
# -> 4566         means.append(do_plot([pos], [stats['mean']], **mean_kw))
#    4567 # maybe draw the fliers
#    4568 if showfliers:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_axes.py:4465, in Axes.bxp.<locals>.do_plot(xs, ys, **kwargs)
#    4464 def do_plot(xs, ys, **kwargs):
# -> 4465     return self.plot(*[xs, ys][maybe_swap], **kwargs)[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_base.py:546, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     544     return list(result)
#     545 else:
# --> 546     return [l[0] for l in result]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_base.py:539, in <genexpr>(.0)
#     534 else:
#     535     raise ValueError(
#     536         f"label must be scalar or have the same length as the input "
#     537         f"data, but found {len(label)} for {n_datasets} datasets.")
# --> 539 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     540                       {**kwargs, 'label': label})
#     541           for j, label in enumerate(labels))
#     543 if return_kwargs:
#     544     return list(result)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_base.py:338, in _process_plot_var_args._make_line(self, axes, x, y, kw, kwargs)
#     336 kw = {**kw, **kwargs}  # Don't modify the original kw.
#     337 self._setdefaults(self._getdefaults(kw), kw)
# --> 338 seg = mlines.Line2D(x, y, **kw)
#     339 return seg, kw
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\lines.py:421, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     417 self.set_markeredgewidth(markeredgewidth)
#     419 # update kwargs before updating data to give the caller a
#     420 # chance to init axes (and hence unit support)
# --> 421 self._internal_update(kwargs)
#     422 self.pickradius = pickradius
#     423 self.ind_offset = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'marherfacecolor'

# %%
sns.boxplot(x='Country',y='National Sales',data=df,showmeans='True',hue='Genre',meanprops={"marker":"o"
                                                                                           ,"marherfacecolor":"white"
                                                                                           ,"markersize":"3"
                                                                                           ,"markeredgecolor":"green"})

# %%
#create A pie chart

Sales=df.groupby(['Country'])[['National Sales','Global Sales']].sum().reset_index()
Country=Sales['Country']
National_Sales=Sales['National Sales']
Global_Sales=Sales['Global Sales']

fig, axs=plt.subplots(1,2,figsize=(10,7))

axs[0].pie(National_Sales, labels=Country, autopct='%1.1f%%',startangle=140)
axs[0].set_title('National Sales  By Country')

axs[1].pie(Global_Sales, labels=Country, autopct='%1.1f%%',startangle=140)
axs[1].set_title('Global Sales  By Country')

plt.show()

# %%
# Create a line chart
plt.figure(figsize=(10, 6))

# Line for National Sales
plt.plot(df['Year'], df['National Sales'], marker='o', linestyle='-', color='b', label='National Sales')

# Line for Global Sales
plt.plot(df['Year'], df['Global Sales'], marker='s', linestyle='--', color='g', label='Global Sales')

# Adding titles and labels
plt.title('National and Global Sales Over Years')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.legend()

# Display the line chart
plt.grid(True)
plt.show()
